# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 9, 6
from sklearn.datasets import make_blobs
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.svm import SVC
from myfun import plot_decision_regions

# %% [markdown]
# # Generate Imbalanced Datasets

# %%
# make 3-class dataset for classification
center1 = [[0, 0]]
X1, y1 = make_blobs(n_samples=800, centers=center1, random_state=42)
center2 = [[0, 0],[1, 1]]
X2, y2 = make_blobs(n_samples=200, centers=center2, random_state=42, cluster_std=0.3)
X = np.vstack((X1, X2))
y = np.hstack((y1, y2))

# %% [markdown]
# 在圖上紅色點表示為壞人(1)，藍色點是好人(0)，今天身為一位警察該如何透過兩個feature從好人中去抓出壞人呢？
# 這邊產生的資料只有10%是壞人 90%是好人

# %%
color = "br"
color = [color[y[i]] for i in range(len(y))]
plt.scatter(X[:,0],X[:,1],c=color)
plt.xlabel('Feature1')
plt.ylabel('Feature2')
# Out:
# Text(0,0.5,'Feature2')

# %% [markdown]
# # Predict with Logistic Regression
# 看看預測結果accuracy有沒有辦法超過90%?

# %% [markdown]
# # Print F1_Score, Precision, Recall

# %% [markdown]
# # 如何讓F1_Score更好？
# 大家可以試著print出logistic regression預測的probability，試著調整threshold看看如何把f1_score做得更好。
