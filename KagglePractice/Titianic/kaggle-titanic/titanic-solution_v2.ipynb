# %% [markdown]
# # Titanic: Machine Learning from Disaster
# ### Predict survival on the Titanic
# - Defining the problem statement
# - Collecting the data
# - Exploratory data analysis
# - Feature engineering
# - Modelling
# - Testing

# %% [markdown]
# ## 1. Defining the problem statement
# Complete the analysis of what sorts of people were likely to survive.
# In particular, we ask you to apply the tools of machine learning to predict which passengers survived the Titanic tragedy.

# %%
from IPython.display import Image
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg"/>

# %% [markdown]
# ## 2. Collecting the data
#
# training data set and testing data set are given by Kaggle
# you can download from
# my github [https://github.com/minsuk-heo/kaggle-titanic/tree/master](https://github.com/minsuk-heo/kaggle-titanic)
# or you can download from kaggle directly [kaggle](https://www.kaggle.com/c/titanic/data)
#
# ### load train, test dataset using Pandas

# %%
import pandas as pd

train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %% [markdown]
# ## 3. Exploratory data analysis
# Printing first 5 rows of the train dataset.

# %%
train.head(80)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# ### Data Dictionary
# - Survived: 	0 = No, 1 = Yes
# - pclass: 	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# - sibsp:	# of siblings / spouses aboard the Titanic
# - parch:	# of parents / children aboard the Titanic
# - ticket:	Ticket number
# - cabin:	Cabin number
# - embarked:	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# **Total rows and columns**
#
# We can see that there are 891 rows and 12 columns in our training dataset.

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# We can see that *Age* value is missing for many rows.
#
# Out of 891 rows, the *Age* value is present only in 714 rows.
#
# Similarly, *Cabin* values are also missing in many rows. Only 204 out of 891 rows have *Cabin* values.

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print(train.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %% [markdown]
# There are 177 rows with missing *Age*, 687 rows with missing *Cabin* and 2 rows with missing *Embarked* information.

# %% [markdown]
# ### import python lib for visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

# %% [markdown]
# ### Bar Chart for Categorical Features
# - Pclass
# - Sex
# - SibSp ( # of siblings and spouse)
# - Parch ( # of parents and children)
# - Embarked
# - Cabin

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bar_chart('Survived')
# sns.countplot(train['Survived'])

# %%
bar_chart('Sex')
# sns.countplot(train['Sex'], hue=train['Survived'])

# %%
train[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %% [markdown]
# The Chart confirms **Women** more likely survivied than **Men**

# %%
bar_chart('Pclass')
# sns.countplot(train['Pclass'], hue=train['Survived'])

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# The Chart confirms **1st class** more likely survivied than **other classes**
# The Chart confirms **3rd class** more likely dead than **other classes**

# %%
bar_chart('SibSp')
# sns.countplot(train['SibSp'], hue=train['Survived'])

# %%
train[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %% [markdown]
# The Chart confirms **a person aboarded with more than 2 siblings or spouse** more likely survived
# The Chart confirms ** a person aboarded without siblings or spouse** more likely dead

# %%
bar_chart('Parch')

# %%
train[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# The Chart confirms **a person aboarded with more than 2 parents or children** more likely survived
# The Chart confirms ** a person aboarded alone** more likely dead

# %%
bar_chart('Embarked')

# %%
train[["Embarked", "Survived"]].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %% [markdown]
# The Chart confirms **a person aboarded from C** slightly more likely survived
# The Chart confirms **a person aboarded from Q** more likely dead
# The Chart confirms **a person aboarded from S** more likely dead

# %% [markdown]
# ## 4. Feature engineering
#
# Feature engineering is the process of using domain knowledge of the data
# to create features (**feature vectors**) that make machine learning algorithms work.
#
# feature vector is an n-dimensional vector of numerical features that represent some object.
# Many algorithms in machine learning require a numerical representation of objects,
# since such representations facilitate processing and statistical analysis.

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 4.1 how titanic sank?
# sank from the bow of the ship where third class rooms located
# conclusion, Pclass is key feature for classifier

# %%
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/t/5090b249e4b047ba54dfd258/1351660113175/TItanic-Survival-Infographic.jpg?format=1500w")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/t/5090b249e4b047ba54dfd258/1351660113175/TItanic-Survival-Infographic.jpg?format=1500w"/>

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### 4.2 Name

# %%
train_test_data = [train, test] # combining train and test dataset
#Extract Title feature using regular expressions. 
#The RegEx pattern (\w+\.) matches the first word which ends with a dot character within Name feature.
for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Col           2
# Mlle          2
# Mme           1
# Countess      1
# Jonkheer      1
# Lady          1
# Sir           1
# Ms            1
# Capt          1
# Don           1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Rev         2
# Col         2
# Dr          1
# Ms          1
# Dona        1
# Name: Title, dtype: int64

# %%
pd.crosstab(train['Title'], train['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col0 {
#             background-color:  #ffff66;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col1 {
#             background-color:  #ffff66;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col2 {
#             background-color:  #008066;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col3 {
#             background-color:  #ffff66;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col4 {
#             background-color:  #ffff66;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col5 {
#             background-color:  #ffff66;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col6 {
#             background-color:  #008066;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col7 {
#             background-color:  #ffff66;
#         }    #T_a1e3456e_34dd_11e8_a75f_9c5c8e35cb7frow0_col8 {
#             background-color:  #ffff66;
# ...

# %%
pd.crosstab(train['Title'], train['Age']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col0 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col1 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col2 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col3 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col4 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col5 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col6 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col7 {
#             background-color:  #ffff66;
#         }    #T_a20b423a_34dd_11e8_9457_9c5c8e35cb7frow0_col8 {
#             background-color:  #cce666;
# ...

# %%
pd.crosstab(test['Title'], test['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col0 {
#             background-color:  #ffff66;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col1 {
#             background-color:  #008066;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col2 {
#             background-color:  #ffff66;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col3 {
#             background-color:  #ffff66;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col4 {
#             background-color:  #008066;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col5 {
#             background-color:  #ffff66;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col6 {
#             background-color:  #008066;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col7 {
#             background-color:  #008066;
#         }    #T_a21c5152_34dd_11e8_b7a5_9c5c8e35cb7frow0_col8 {
#             background-color:  #ffff66;
# ...

# %%
#Mr          517
# Miss        182
# Mrs         125
# Master       40

# title_mapping = {"Ms":0, "Mrs":0, "Lady":0, "Mlle":0, "Countess":0,
#                  "Miss":1,
#                  "Master":2, 
#                  "Mr":3, "Sir": 3, "Capt":3, "Mme":3, "Dr":3, "Rev":3, 
#                  "Col":3, "Major":3, "Jonkheer":3, "Don":3, "Dona":3}

# %%
title_mapping = {"Ms":"Ms", "Mrs":"Ms", "Lady":"Ms", "Mlle":"Ms", "Countess":"Ms",
                 "Miss":"Miss",
                 "Master":"Master", 
                 "Mr":"Mr", "Sir": "Mr", "Capt":"Mr", "Mme":"Mr", "Dr":"Mr", "Rev":"Mr", 
                 "Col":"Mr", "Major":"Mr", "Jonkheer":"Mr", "Don":"Mr", "Dona":"Mr"}
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
# dummy = pd.get_dummies(train['Title'])
# train= pd.concat([train,dummy], axis=1)
# test = pd.concat([test,dummy], axis=1)
# train_test_data = [train, test]

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C    Ms
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S    Ms
# ...

# %%
bar_chart('Title')

# %% [markdown]
# ### 4.3 Sex
#
# male: 0
# female: 1

# %%
# sex_mapping = {"male": 0, "female": 1}
# for dataset in train_test_data:
#     dataset['Sex'] = dataset['Sex'].map(sex_mapping)
# dummy = pd.get_dummies(train['Sex'])
# train = pd.concat([train,dummy], axis=1)
# test = pd.concat([test,dummy], axis=1)
# train_test_data = [train, test]

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C    Ms
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S    Ms
# ...

# %%
bar_chart('Sex')

# %% [markdown]
# ### 4.4 Age

# %% [markdown]
# #### 4.4.1 some age is missing
# Let's use Title's median age for missing Age

# %%
train.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
# fill missing age with median age for each title (Mr, Mrs, Miss, Others)
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("median"), inplace=True)

# %%
train.Age.isnull().sum()
# Out:
# 0

# %%
# train.groupby("Title")["Age"].transform("median")

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0, 20)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(20, 30)
# Out:
# (20, 30)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(30, 40)
# Out:
# (30, 40)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40, 60)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40, 60)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(60)
# Out:
# (60, 80.0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Title          418 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 39.3+ KB

# %% [markdown]
# #### 4.4.2 Binning
# Binning/Converting Numerical Age to Categorical Variable
#
# feature vector map:
# child: 0
# young: 1
# adult: 2
# mid-age: 3
# senior: 4

# %%
train['AgeBand'] = pd.cut(train['Age'], 5)
train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#             AgeBand  Survived
# 0    (0.34, 16.336]  0.548077
# 1  (16.336, 32.252]  0.326693
# 2  (32.252, 48.168]  0.439024
# 3  (48.168, 64.084]  0.434783
# 4    (64.084, 80.0]  0.090909

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 16, 'AgeRge'] = 'Age16',
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'AgeRge'] = 'Age26',
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'AgeRge'] = 'Age36',
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 64), 'AgeRge'] = 'Age64',
    dataset.loc[ dataset['Age'] > 64, 'AgeRge'] = 'OverAge64'

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title           AgeBand  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr  (16.336, 32.252]
# 1      0          PC 17599  71.2833   C85        C    Ms  (32.252, 48.168]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss  (16.336, 32.252]
# ...

# %%
bar_chart('AgeBand')

# %%
train[["AgeRge", "Survived"]].groupby(['AgeRge'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       AgeRge  Survived
# 0      Age16  0.548077
# 3      Age64  0.385870
# 1      Age26  0.380392
# 2      Age36  0.344214
# 4  OverAge64  0.090909

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] < 16, 'Marked'] = 'teenager',
    dataset.loc[(dataset['Age'] >= 16) & (dataset['Sex'] == 'Male'), 'Marked'] = 'Man',
    dataset.loc[(dataset['Age'] >= 16) & (dataset['Sex'] == 'Female'), 'Marked'] = 'Woman'
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title AgeRge Marked
# 0      0         A/5 21171   7.2500   NaN        S    Mr  Age26    NaN
# 1      0          PC 17599  71.2833   C85        C    Ms  Age64    NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss  Age26    NaN
# ...

# %%
train.drop('AgeBand', axis=1, inplace=True)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title AgeRge Marked
# 0      0         A/5 21171   7.2500   NaN        S    Mr  Age26    NaN
# 1      0          PC 17599  71.2833   C85        C    Ms  Age64    NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss  Age26    NaN
# ...

# %% [markdown]
# ### 4.5 Embarked

# %% [markdown]
# #### 4.5.1 filling missing values

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# more than 50% of 1st class are from S embark
# more than 50% of 2nd class are from S embark
# more than 50% of 3rd class are from S embark
#
# **fill out missing embark with S embark**

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title AgeRge Marked
# 0      0         A/5 21171   7.2500   NaN        S    Mr  Age26    NaN
# 1      0          PC 17599  71.2833   C85        C    Ms  Age64    NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss  Age26    NaN
# ...

# %%
# embarked_mapping = {"S": 0, "C": 1, "Q": 2}
# for dataset in train_test_data:
#     dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %%
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %% [markdown]
# ### 4.6 Fare

# %%
# fill missing Fare with median fare for each Pclass
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title AgeRge Marked
# 0      0         A/5 21171   7.2500   NaN        S    Mr  Age26    NaN
# 1      0          PC 17599  71.2833   C85        C    Ms  Age64    NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss  Age26    NaN
# ...

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
 
plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(40, 120)
# Out:
# (40, 120)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 512.3292)

# %%
train['FareBand'] = pd.qcut(train['Fare'], 4)
train[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 8, 'FareRge'] = 'Lower',
    dataset.loc[(dataset['Fare'] > 8) & (dataset['Fare'] <= 15), 'FareRge'] = 'Low',
    dataset.loc[(dataset['Fare'] > 15) & (dataset['Fare'] <= 30), 'FareRge'] = 'High',
    dataset.loc[ dataset['Fare'] > 30, 'FareRge'] = 'Higher'

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title AgeRge Marked  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr  Age26    NaN
# 1      0          PC 17599  71.2833   C85        C    Ms  Age64    NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss  Age26    NaN
# ...

# %% [markdown]
# ### 4.7 Cabin

# %%
# train.Cabin.value_counts()

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

train.Cabin.value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# Name: Cabin, dtype: int64

# %%
print(train.Cabin.isnull().sum())
print(test.Cabin.isnull().sum())
# Out:
# 687
# 327

# %%
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
cabin_mapping = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)
    
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Cabin Embarked Title AgeRge Marked  \
# 0      0         A/5 21171   7.2500    NaN        S    Mr  Age26    NaN
# 1      0          PC 17599  71.2833    0.8        C    Ms  Age64    NaN
# 2      0  STON/O2. 3101282   7.9250    NaN        S  Miss  Age26    NaN
# ...

# %%
# fill missing Fare with median fare for each Pclass
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Cabin Embarked Title AgeRge Marked  \
# 0      0         A/5 21171   7.2500    2.0        S    Mr  Age26    NaN
# 1      0          PC 17599  71.2833    0.8        C    Ms  Age64    NaN
# 2      0  STON/O2. 3101282   7.9250    2.0        S  Miss  Age26    NaN
# ...

# %%
train.Cabin.unique()
# Out:
# array([2. , 0.8, 1.6, 1.8, 2.4, 1.2, 0. , 0.4, 2.8])

# %%
test.Cabin.unique()
# Out:
# array([2. , 0.8, 0.4, 1.6, 0. , 1.2, 2.4])

# %% [markdown]
# ### 4.8 FamilySize

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 10.0)

# %%
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %%
# features_drop = ['Ticket', 'SibSp', 'Parch','Name','Sex','Age','FareBand']
# train = train.drop(features_drop, axis=1)

# test = test.drop(features_drop, axis=1)
# train = train.drop(['PassengerId'], axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Fare  Cabin Embarked Title AgeRge Marked  \
# 0            1         0       3   7.2500    2.0        S    Mr  Age26    NaN
# 1            2         1       1  71.2833    0.8        C    Ms  Age64    NaN
# 2            3         1       3   7.9250    2.0        S  Miss  Age26    NaN
# 3            4         1       1  53.1000    0.8        S    Ms  Age36    NaN
# 4            5         0       3   8.0500    2.0        S    Mr  Age36    NaN
#
#   FareRge  FamilySize
# 0   Lower         0.0
# 1  Higher         0.0
# 2   Lower         NaN
# 3  Higher         0.0
# 4     Low         NaN

# %%
test.head()

# %% [markdown]
# ## 5. Modelling

# %%
# Importing Classifier Modules
from sklearn.linear_model import LogisticRegression,Perceptron, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import train_test_split, KFold, cross_val_score

k_fold = KFold(n_splits=20, shuffle=True, random_state=7)

# %%
X = train.drop("Survived", axis=1)
y = train["Survived"]

X_test  = test.drop("PassengerId", axis=1).copy()

# %%
X_train, X_vhttp://localhost:8888/notebooks/WorkSpace/01_KaggleSample/Titianic/kaggle-titanic/titanic-solution_v2.ipynb#Logistic-Regressional, y_train, y_val = train_test_split(X, y, 
                                                    test_size=0.2, 
                                                    random_state=7)
X_train.shape, y_train.shape, X_val.shape

# %% [markdown]
# ### Logistic Regression

# %%
logreg = LogisticRegression()
scoring = 'accuracy'
logreg.fit(X_train, y_train)
# Y_pred = logreg.predict(X_test)
score = cross_val_score(logreg, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
# print(score)
print(score.mean())

# acc_log = round(logreg.score(X_train, y_train) * 100, 2)
# acc_log

# %%
coeff_df = pd.DataFrame(train.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])
coeff_df.sort_values(by='Correlation', ascending=False)

# %% [markdown]
# ### SVM

# %%
svm = SVC()
scoring = 'accuracy'
svm.fit(X_train, y_train)
score = cross_val_score(svm, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
# print(score)
print(score.mean())

Y_pred = svm.predict(X_test)

# %% [markdown]
# ### Linear SVC

# %%
linear_svc = LinearSVC()
scoring = 'accuracy'
linear_svc.fit(X_train, y_train)
# Y_pred = linear_svc.predict(X_test)
score = cross_val_score(linear_svc, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())
# acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
# acc_linear_svc

# %% [markdown]
# ### kNN

# %%
knn = KNeighborsClassifier(n_neighbors = 8)
scoring = 'accuracy'
# Y_pred = perceptron.predict(X_test)
score = cross_val_score(knn, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())

# %% [markdown]
# ### Perceptron

# %%
perceptron = Perceptron()
scoring = 'accuracy'
perceptron.fit(X_train, y_train)
# Y_pred = perceptron.predict(X_test)
score = cross_val_score(perceptron, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())

# %% [markdown]
# ### Naive Bayes

# %%
nb = GaussianNB()
scoring = 'accuracy'
nb.fit(X_train, y_train)
score = cross_val_score(nb, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
# print(score)
print(score.mean())

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
sgd = SGDClassifier()
scoring = 'accuracy'
sgd.fit(X_train, y_train)
# Y_pred = sgd.predict(X_test)
score = cross_val_score(sgd, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())

# %% [markdown]
# ### Decision Tree

# %%
decision_tree = DecisionTreeClassifier()
scoring = 'accuracy'
decision_tree.fit(X_train, y_train)
# Y_pred = decision_tree.predict(X_test)
score = cross_val_score(decision_tree, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score.mean())

# %% [markdown]
# ### 6.2.3 Ramdom Forest

# %%
random_forest = RandomForestClassifier(n_estimators=100)
scoring = 'accuracy'
random_forest.fit(X_train, y_train)
# Y_pred = random_forest.predict(X_test)
score = cross_val_score(random_forest, X_train, y_train, cv=k_fold, n_jobs=1, scoring=scoring)
# print(score)
print(score.mean())

# %% [markdown]
# ## 7. Testing

# %%
svm = SVC()
svm.fit(X_train, y_train)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = svm.predict(X_test)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })
submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
